# %%
# English-French sentence pairs
pairs = [
    ("I am cold", "J'ai froid"),
    ("You are tired", "Tu es fatigué"),
    ("He is hungry", "Il a faim"),
    ("She is happy", "Elle est heureuse"),
    ("We are friends", "Nous sommes amis"),
    ("They are students", "Ils sont étudiants"),
    ("The cat is sleeping", "Le chat dort"),
    ("The sun is shining", "Le soleil brille"),
    ("We love music", "Nous aimons la musique"),
    ("She speaks French fluently", "Elle parle français couramment"),
    ("He enjoys reading books", "Il aime lire des livres"),
    ("They play soccer every weekend", "Ils jouent au football chaque week-end"),
    ("The movie starts at 7 PM", "Le film commence à 19 heures"),
    ("She wears a red dress", "Elle porte une robe rouge"),
    ("We cook dinner together", "Nous cuisinons le dîner ensemble"),
    ("He drives a blue car", "Il conduit une voiture bleue"),
    ("They visit museums often", "Ils visitent souvent des musées"),
    ("The restaurant serves delicious food", "Le restaurant sert une délicieuse cuisine"),
    ("She studies mathematics at university", "Elle étudie les mathématiques à l'université"),
    ("We watch movies on Fridays", "Nous regardons des films le vendredi"),
    ("He listens to music while jogging", "Il écoute de la musique en faisant du jogging"),
    ("They travel around the world", "Ils voyagent autour du monde"),
    ("The book is on the table", "Le livre est sur la table"),
    ("She dances gracefully", "Elle danse avec grâce"),
    ("We celebrate birthdays with cake", "Nous célébrons les anniversaires avec un gâteau"),
    ("He works hard every day", "Il travaille dur tous les jours"),
    ("They speak different languages", "Ils parlent différentes langues"),
    ("The flowers bloom in spring", "Les fleurs fleurissent au printemps"),
    ("She writes poetry in her free time", "Elle écrit de la poésie pendant son temps libre"),
    ("We learn something new every day", "Nous apprenons quelque chose de nouveau chaque jour"),
    ("The dog barks loudly", "Le chien aboie bruyamment"),
    ("He sings beautifully", "Il chante magnifiquement"),
    ("They swim in the pool", "Ils nagent dans la piscine"),
    ("The birds chirp in the morning", "Les oiseaux gazouillent le matin"),
    ("She teaches English at school", "Elle enseigne l'anglais à l'école"),
    ("We eat breakfast together", "Nous prenons le petit déjeuner ensemble"),
    ("He paints landscapes", "Il peint des paysages"),
    ("They laugh at the joke", "Ils rient de la blague"),
    ("The clock ticks loudly", "L'horloge tic-tac bruyamment"),
    ("She runs in the park", "Elle court dans le parc"),
    ("We travel by train", "Nous voyageons en train"),
    ("He writes a letter", "Il écrit une lettre"),
    ("They read books at the library", "Ils lisent des livres à la bibliothèque"),
    ("The baby cries", "Le bébé pleure"),
    ("She studies hard for exams", "Elle étudie dur pour les examens"),
    ("We plant flowers in the garden", "Nous plantons des fleurs dans le jardin"),
    ("He fixes the car", "Il répare la voiture"),
    ("They drink coffee in the morning", "Ils boivent du café le matin"),
    ("The sun sets in the evening", "Le soleil se couche le soir"),
    ("She dances at the party", "Elle danse à la fête"),
    ("We play music at the concert", "Nous jouons de la musique au concert"),
    ("He cooks dinner for his family", "Il cuisine le dîner pour sa famille"),
    ("They study French grammar", "Ils étudient la grammaire française"),
    ("The rain falls gently", "La pluie tombe doucement"),
    ("She sings a song", "Elle chante une chanson"),
    ("We watch a movie together", "Nous regardons un film ensemble"),
    ("He sleeps deeply", "Il dort profondément"),
    ("They travel to Paris", "Ils voyagent à Paris"),
    ("The children play in the park", "Les enfants jouent dans le parc"),
    ("She walks along the beach", "Elle se promène le long de la plage"),
    ("We talk on the phone", "Nous parlons au téléphone"),
    ("He waits for the bus", "Il attend le bus"),
    ("They visit the Eiffel Tower", "Ils visitent la tour Eiffel"),
    ("The stars twinkle at night", "Les étoiles scintillent la nuit"),
    ("She dreams of flying", "Elle rêve de voler"),
    ("We work in the office", "Nous travaillons au bureau"),
    ("He studies history", "Il étudie l'histoire"),
    ("They listen to the radio", "Ils écoutent la radio"),
    ("The wind blows gently", "Le vent souffle doucement"),
    ("She swims in the ocean", "Elle nage dans l'océan"),
    ("We dance at the wedding", "Nous dansons au mariage"),
    ("He climbs the mountain", "Il gravit la montagne"),
    ("They hike in the forest", "Ils font de la randonnée dans la forêt"),
    ("The cat meows loudly", "Le chat miaule bruyamment"),
    ("She paints a picture", "Elle peint un tableau"),
    ("We build a sandcastle", "Nous construisons un château de sable"),
    ("He sings in the choir", "Il chante dans le chœur"),
    ("They ride bicycles", "Ils font du vélo"),
    ("The coffee is hot", "Le café est chaud"),
    ("She wears glasses", "Elle porte des lunettes"),
    ("We visit our grandparents", "Nous rendons visite à nos grands-parents"),
    ("He plays the guitar", "Il joue de la guitare"),
    ("They go shopping", "Ils font du shopping"),
    ("The teacher explains the lesson", "Le professeur explique la leçon"),
    ("She takes the train to work", "Elle prend le train pour aller au travail"),
    ("We bake cookies", "Nous faisons des biscuits"),
    ("He washes his hands", "Il se lave les mains"),
    ("They enjoy the sunset", "Ils apprécient le coucher du soleil"),
    ("The river flows calmly", "La rivière coule calmement"),
    ("She feeds the cat", "Elle nourrit le chat"),
    ("We visit the museum", "Nous visitons le musée"),
    ("He fixes his bicycle", "Il répare son vélo"),
    ("They paint the walls", "Ils peignent les murs"),
    ("The baby sleeps peacefully", "Le bébé dort paisiblement"),
    ("She ties her shoelaces", "Elle attache ses lacets"),
    ("We climb the stairs", "Nous montons les escaliers"),
    ("He shaves in the morning", "Il se rase le matin"),
    ("They set the table", "Ils mettent la table"),
    ("The airplane takes off", "L'avion décolle"),
    ("She waters the plants", "Elle arrose les plantes"),
    ("We practice yoga", "Nous pratiquons le yoga"),
    ("He turns off the light", "Il éteint la lumière"),
    ("They play video games", "Ils jouent aux jeux vidéo"),
    ("The soup smells delicious", "La soupe sent délicieusement bon"),
    ("She locks the door", "Elle ferme la porte à clé"),
    ("We enjoy a picnic", "Nous profitons d'un pique-nique"),
    ("He checks his email", "Il vérifie ses emails"),
    ("They go to the gym", "Ils vont à la salle de sport"),
    ("The moon shines brightly", "La lune brille intensément"),
    ("She catches the bus", "Elle attrape le bus"),
    ("We greet our neighbors", "Nous saluons nos voisins"),
    ("He combs his hair", "Il se peigne les cheveux"),
    ("They wave goodbye", "Ils font un signe d'adieu")

]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence
import matplotlib.pyplot as plt
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

###############################################################################
# 1) Sample English->French Pairs (Character Level)
###############################################################################

# Add <bos> and <eos> to each target.
def add_special_tokens(en, fr):
    bos_token = "<bos>"
    eos_token = "<eos>"
    return en, bos_token + " " + fr + " " + eos_token

updated_pairs = []
for en, fr in pairs:
    en_text, fr_text = add_special_tokens(en, fr)
    updated_pairs.append((en_text, fr_text))

all_text = ""
for en, fr in updated_pairs:
    all_text += en + fr

chars = sorted(list(set(all_text)))
char_to_int = {ch: i for i, ch in enumerate(chars)}
int_to_char = {i: ch for ch, i in char_to_int.items()}

def encode(text):
    return [char_to_int[ch] for ch in text]

def decode(indices):
    return "".join(int_to_char[i] for i in indices)

encoded_src = [encode(en) for en, _ in updated_pairs]
encoded_tgt = [encode(fr) for _, fr in updated_pairs]

###############################################################################
# 2) Dataset and DataLoader
###############################################################################
class TranslationDataset(Dataset):
    def __init__(self, sources, targets):
        self.sources = sources
        self.targets = targets

    def __len__(self):
        return len(self.sources)

    def __getitem__(self, idx):
        src_seq = torch.tensor(self.sources[idx], dtype=torch.long)
        tgt_seq = torch.tensor(self.targets[idx], dtype=torch.long)
        return src_seq, tgt_seq

def collate_fn(batch):
    src_list, tgt_list = zip(*batch)
    src_padded = pad_sequence(src_list, batch_first=True, padding_value=0)
    tgt_padded = pad_sequence(tgt_list, batch_first=True, padding_value=0)
    return src_padded, tgt_padded

dataset = TranslationDataset(encoded_src, encoded_tgt)
train_size = int(len(dataset) * 0.8)
val_size = len(dataset) - train_size
train_ds, val_ds = random_split(dataset, [train_size, val_size])

batch_size = 8
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

###############################################################################
# 3) Standard Transformer Encoder-Decoder
###############################################################################
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_size, num_layers, nhead, forward_expansion=512, dropout=0.1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_size, 
            nhead=nhead,
            dim_feedforward=forward_expansion,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

    def forward(self, x):
        embedded = self.embedding(x)
        output = self.transformer_encoder(embedded)
        return output

class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_size, num_layers, nhead, forward_expansion=512, dropout=0.1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        decoder_layer = nn.TransformerDecoderLayer(
            d_model=embed_size,
            nhead=nhead,
            dim_feedforward=forward_expansion,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=num_layers)
        self.fc_out = nn.Linear(embed_size, vocab_size)

    def forward(self, tgt, enc_out):
        embedded = self.embedding(tgt)
        dec_out = self.transformer_decoder(embedded, enc_out)
        output = self.fc_out(dec_out)
        return output

class Seq2SeqTransformer(nn.Module):
    def __init__(self, vocab_size, embed_size, enc_layers, dec_layers, nhead, forward_expansion=512, dropout=0.1):
        super().__init__()
        self.encoder = Encoder(vocab_size, embed_size, enc_layers, nhead, forward_expansion, dropout)
        self.decoder = Decoder(vocab_size, embed_size, dec_layers, nhead, forward_expansion, dropout)

    def forward(self, src, tgt):
        enc_out = self.encoder(src)
        dec_out = self.decoder(tgt, enc_out)
        return dec_out

###############################################################################
# 4) Training and Evaluation
###############################################################################
def train_one_epoch(model, optimizer, criterion, loader):
    model.train()
    total_loss = 0
    for src, tgt in loader:
        src, tgt = src.to(device), tgt.to(device)
        # Decoder: use tgt[:, :-1] -> predict tgt[:, 1:]
        tgt_inp = tgt[:, :-1]
        tgt_label = tgt[:, 1:]

        optimizer.zero_grad()
        output = model(src, tgt_inp)  # [batch, tgt_len-1, vocab_size]
        # Flatten
        output_flat = output.reshape(-1, output.shape[-1])
        tgt_label_flat = tgt_label.reshape(-1)

        loss = criterion(output_flat, tgt_label_flat)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, criterion, loader):
    model.eval()
    total_loss = 0
    correct_tokens = 0
    total_tokens = 0
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            tgt_inp = tgt[:, :-1]
            tgt_label = tgt[:, 1:]
            output = model(src, tgt_inp)
            output_flat = output.reshape(-1, output.shape[-1])
            tgt_label_flat = tgt_label.reshape(-1)

            loss = criterion(output_flat, tgt_label_flat)
            total_loss += loss.item()

            preds = torch.argmax(output, dim=-1)  # [batch, tgt_len-1]
            # Compare preds with tgt_label
            matches = (preds == tgt_label)
            correct_tokens += matches.sum().item()
            total_tokens += matches.numel()

    avg_loss = total_loss / len(loader)
    accuracy = correct_tokens / total_tokens if total_tokens > 0 else 0.0
    return avg_loss, accuracy

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def train_model(model, train_loader, val_loader, epochs, lr):
    model.to(device)
    criterion = nn.CrossEntropyLoss(ignore_index=0)  # pad value = 0
    optimizer = optim.Adam(model.parameters(), lr=lr)
    train_losses, val_losses, val_accs = [], [], []
    for epoch in range(epochs):
        train_loss = train_one_epoch(model, optimizer, criterion, train_loader)
        val_loss, val_acc = evaluate(model, criterion, val_loader)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        print(f"Epoch [{epoch+1}/{epochs}] | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    return train_losses, val_losses, val_accs

###############################################################################
# 5) Main Loop for 8 Configurations
###############################################################################
enc_dec_configs = [
    (1,1),
    (1,2),
    (2,2),
    (2,4),
    (4,2),
    (4,4),
    # If you literally need 8 combos with heads=2 or 4, you can adjust as needed
    # E.g., (1,4), (2,4), (4,4), etc.
    # Make sure you list all 8. This is a demonstration.
]

epochs_num = 10     # For demonstration. Increase for better results
embed_size = 64
learning_rate = 1e-3

results = []
for (enc_l, dec_l) in enc_dec_configs:
    for nheads in [2, 4]:  # you can also pair them differently if you want
        print("\n==========================================")
        print(f"Running config: Encoder={enc_l}, Decoder={dec_l}, Heads={nheads}")

        model = Seq2SeqTransformer(
            vocab_size=len(chars),
            embed_size=embed_size,
            enc_layers=enc_l,
            dec_layers=dec_l,
            nhead=nheads
        )

        start_time = time.time()
        train_losses, val_losses, val_accs = train_model(model, train_loader, val_loader, epochs_num, learning_rate)
        end_time = time.time()

        final_train_loss = train_losses[-1]
        final_val_loss = val_losses[-1]
        final_val_acc = val_accs[-1]
        avg_time = (end_time - start_time) / epochs_num
        model_params = count_parameters(model)

        # Plotting
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(train_losses, label='Train Loss')
        plt.plot(val_losses, label='Val Loss')
        plt.title(f"Loss (Enc={enc_l}, Dec={dec_l}, Heads={nheads})")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(val_accs, label='Val Accuracy')
        plt.title(f"Accuracy (Enc={enc_l}, Dec={dec_l}, Heads={nheads})")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.tight_layout()
        plt.show()

        print("========================================== results ==========================================")
        print(f"final training loss: {final_train_loss:.4f}, final validation loss: {final_val_loss:.4f}, final validation accuracy: {final_val_acc:.4f}")
        print(f"Average running time: {avg_time:.4f} seconds per epoch")
        print(f"model complexity (number of parameters): {model_params}")
        print("============================================================================================")

        results.append((enc_l, dec_l, nheads, final_train_loss, final_val_loss, final_val_acc, avg_time, model_params))

###############################################################################
# 6) Summary of all runs
###############################################################################
print("\nSummary of all runs:")
for res in results:
    el, dl, nh, trl, vl, va, t, mp = res
    print(f"Enc={el}, Dec={dl}, Heads={nh}, final_train_loss={trl:.4f}, final_val_loss={vl:.4f}, final_val_acc={va:.4f}, time/epoch={t:.4f}s, params={mp}")
# Out:
# ==========================================
# Running config: Encoder=1, Decoder=1, Heads=2
# Epoch [1/10] | Train Loss: 3.3454 | Val Loss: 2.8064 | Val Acc: 0.1932
# Epoch [2/10] | Train Loss: 2.6232 | Val Loss: 2.3862 | Val Acc: 0.2314
# Epoch [3/10] | Train Loss: 2.3353 | Val Loss: 2.2153 | Val Acc: 0.2426
# Epoch [4/10] | Train Loss: 2.2069 | Val Loss: 2.1456 | Val Acc: 0.2409
# Epoch [5/10] | Train Loss: 2.0957 | Val Loss: 2.0940 | Val Acc: 0.2418
# Epoch [6/10] | Train Loss: 2.0418 | Val Loss: 2.0659 | Val Acc: 0.2496
# Epoch [7/10] | Train Loss: 2.0095 | Val Loss: 2.0431 | Val Acc: 0.2530
# Epoch [8/10] | Train Loss: 1.9784 | Val Loss: 2.0203 | Val Acc: 0.2504
# Epoch [9/10] | Train Loss: 1.9478 | Val Loss: 1.9886 | Val Acc: 0.2548
# Epoch [10/10] | Train Loss: 1.9204 | Val Loss: 1.9808 | Val Acc: 0.2522
# ========================================== results ==========================================
# final training loss: 1.9204, final validation loss: 1.9808, final validation accuracy: 0.2522
# Average running time: 0.0775 seconds per epoch
# model complexity (number of parameters): 193399
# ============================================================================================
#
# ==========================================
# Running config: Encoder=1, Decoder=1, Heads=4
# Epoch [1/10] | Train Loss: 3.5180 | Val Loss: 2.9218 | Val Acc: 0.1733
# Epoch [2/10] | Train Loss: 2.7118 | Val Loss: 2.4413 | Val Acc: 0.2279
# Epoch [3/10] | Train Loss: 2.3745 | Val Loss: 2.2458 | Val Acc: 0.2452
# Epoch [4/10] | Train Loss: 2.2160 | Val Loss: 2.1556 | Val Acc: 0.2435
# Epoch [5/10] | Train Loss: 2.1314 | Val Loss: 2.1058 | Val Acc: 0.2435
# Epoch [6/10] | Train Loss: 2.0493 | Val Loss: 2.0505 | Val Acc: 0.2530
# Epoch [7/10] | Train Loss: 2.0104 | Val Loss: 2.0365 | Val Acc: 0.2487
# Epoch [8/10] | Train Loss: 1.9805 | Val Loss: 2.0217 | Val Acc: 0.2487
# Epoch [9/10] | Train Loss: 1.9532 | Val Loss: 1.9996 | Val Acc: 0.2539
# Epoch [10/10] | Train Loss: 1.9173 | Val Loss: 1.9964 | Val Acc: 0.2600
# ========================================== results ==========================================
# final training loss: 1.9173, final validation loss: 1.9964, final validation accuracy: 0.2600
# Average running time: 0.0631 seconds per epoch
# model complexity (number of parameters): 193399
# ============================================================================================
#
# ==========================================
# Running config: Encoder=1, Decoder=2, Heads=2
# Epoch [1/10] | Train Loss: 3.1796 | Val Loss: 2.6629 | Val Acc: 0.2184
# Epoch [2/10] | Train Loss: 2.5109 | Val Loss: 2.3320 | Val Acc: 0.2357
# Epoch [3/10] | Train Loss: 2.2515 | Val Loss: 2.2026 | Val Acc: 0.2435
# Epoch [4/10] | Train Loss: 2.1327 | Val Loss: 2.1202 | Val Acc: 0.2461
# Epoch [5/10] | Train Loss: 2.0765 | Val Loss: 2.0736 | Val Acc: 0.2478
# Epoch [6/10] | Train Loss: 2.0113 | Val Loss: 2.0583 | Val Acc: 0.2452
# Epoch [7/10] | Train Loss: 1.9822 | Val Loss: 2.0428 | Val Acc: 0.2487
# Epoch [8/10] | Train Loss: 1.9475 | Val Loss: 2.0136 | Val Acc: 0.2548
# Epoch [9/10] | Train Loss: 1.9178 | Val Loss: 2.0133 | Val Acc: 0.2513
# Epoch [10/10] | Train Loss: 1.9144 | Val Loss: 1.9870 | Val Acc: 0.2496
# ========================================== results ==========================================
# final training loss: 1.9144, final validation loss: 1.9870, final validation accuracy: 0.2496
# Average running time: 0.1015 seconds per epoch
# model complexity (number of parameters): 293175
# ============================================================================================
#
# ==========================================
# Running config: Encoder=1, Decoder=2, Heads=4
# Epoch [1/10] | Train Loss: 3.3347 | Val Loss: 2.7760 | Val Acc: 0.1950
# Epoch [2/10] | Train Loss: 2.6038 | Val Loss: 2.3683 | Val Acc: 0.2322
# Epoch [3/10] | Train Loss: 2.3291 | Val Loss: 2.2208 | Val Acc: 0.2452
# Epoch [4/10] | Train Loss: 2.1622 | Val Loss: 2.1328 | Val Acc: 0.2487
# Epoch [5/10] | Train Loss: 2.0763 | Val Loss: 2.0892 | Val Acc: 0.2444
# Epoch [6/10] | Train Loss: 2.0377 | Val Loss: 2.0536 | Val Acc: 0.2513
# Epoch [7/10] | Train Loss: 1.9705 | Val Loss: 2.0269 | Val Acc: 0.2582
# Epoch [8/10] | Train Loss: 1.9658 | Val Loss: 2.0061 | Val Acc: 0.2556
# Epoch [9/10] | Train Loss: 1.9073 | Val Loss: 1.9755 | Val Acc: 0.2600
# Epoch [10/10] | Train Loss: 1.8741 | Val Loss: 1.9652 | Val Acc: 0.2600
# ========================================== results ==========================================
# final training loss: 1.8741, final validation loss: 1.9652, final validation accuracy: 0.2600
# Average running time: 0.0884 seconds per epoch
# model complexity (number of parameters): 293175
# ============================================================================================
#
# ==========================================
# Running config: Encoder=2, Decoder=2, Heads=2
# Epoch [1/10] | Train Loss: 3.2863 | Val Loss: 2.7457 | Val Acc: 0.2019
# Epoch [2/10] | Train Loss: 2.5747 | Val Loss: 2.3885 | Val Acc: 0.2305
# Epoch [3/10] | Train Loss: 2.3265 | Val Loss: 2.2347 | Val Acc: 0.2392
# Epoch [4/10] | Train Loss: 2.1763 | Val Loss: 2.1361 | Val Acc: 0.2418
# Epoch [5/10] | Train Loss: 2.0800 | Val Loss: 2.0828 | Val Acc: 0.2461
# Epoch [6/10] | Train Loss: 2.0312 | Val Loss: 2.0562 | Val Acc: 0.2513
# Epoch [7/10] | Train Loss: 1.9988 | Val Loss: 2.0573 | Val Acc: 0.2357
# Epoch [8/10] | Train Loss: 1.9446 | Val Loss: 2.0099 | Val Acc: 0.2548
# Epoch [9/10] | Train Loss: 1.9182 | Val Loss: 1.9893 | Val Acc: 0.2522
# Epoch [10/10] | Train Loss: 1.8791 | Val Loss: 1.9627 | Val Acc: 0.2548
# ========================================== results ==========================================
# final training loss: 1.8791, final validation loss: 1.9627, final validation accuracy: 0.2548
# Average running time: 0.1152 seconds per epoch
# model complexity (number of parameters): 376183
# ============================================================================================
#
# ==========================================
# Running config: Encoder=2, Decoder=2, Heads=4
# Epoch [1/10] | Train Loss: 3.1612 | Val Loss: 2.6006 | Val Acc: 0.2175
# Epoch [2/10] | Train Loss: 2.4601 | Val Loss: 2.2697 | Val Acc: 0.2426
# Epoch [3/10] | Train Loss: 2.2287 | Val Loss: 2.1729 | Val Acc: 0.2461
# Epoch [4/10] | Train Loss: 2.1157 | Val Loss: 2.0949 | Val Acc: 0.2461
# Epoch [5/10] | Train Loss: 2.0453 | Val Loss: 2.0489 | Val Acc: 0.2487
# Epoch [6/10] | Train Loss: 1.9976 | Val Loss: 2.0182 | Val Acc: 0.2539
# Epoch [7/10] | Train Loss: 1.9608 | Val Loss: 1.9990 | Val Acc: 0.2530
# Epoch [8/10] | Train Loss: 1.9199 | Val Loss: 1.9804 | Val Acc: 0.2600
# Epoch [9/10] | Train Loss: 1.8917 | Val Loss: 1.9704 | Val Acc: 0.2565
# Epoch [10/10] | Train Loss: 1.8428 | Val Loss: 1.9685 | Val Acc: 0.2600
# ========================================== results ==========================================
# final training loss: 1.8428, final validation loss: 1.9685, final validation accuracy: 0.2600
# Average running time: 0.1142 seconds per epoch
# model complexity (number of parameters): 376183
# ============================================================================================
#
# ==========================================
# Running config: Encoder=2, Decoder=4, Heads=2
# Epoch [1/10] | Train Loss: 3.2184 | Val Loss: 2.6814 | Val Acc: 0.1941
# Epoch [2/10] | Train Loss: 2.5336 | Val Loss: 2.3464 | Val Acc: 0.2452
# Epoch [3/10] | Train Loss: 2.2985 | Val Loss: 2.2019 | Val Acc: 0.2478
# Epoch [4/10] | Train Loss: 2.1398 | Val Loss: 2.1114 | Val Acc: 0.2496
# Epoch [5/10] | Train Loss: 2.0721 | Val Loss: 2.0825 | Val Acc: 0.2444
# Epoch [6/10] | Train Loss: 2.0111 | Val Loss: 2.0508 | Val Acc: 0.2461
# Epoch [7/10] | Train Loss: 1.9566 | Val Loss: 2.0190 | Val Acc: 0.2530
# Epoch [8/10] | Train Loss: 1.9392 | Val Loss: 1.9988 | Val Acc: 0.2556
# Epoch [9/10] | Train Loss: 1.8924 | Val Loss: 1.9991 | Val Acc: 0.2496
# Epoch [10/10] | Train Loss: 1.8673 | Val Loss: 1.9597 | Val Acc: 0.2600
# ========================================== results ==========================================
# final training loss: 1.8673, final validation loss: 1.9597, final validation accuracy: 0.2600
# Average running time: 0.1608 seconds per epoch
# model complexity (number of parameters): 575735
# ============================================================================================
#
# ==========================================
# Running config: Encoder=2, Decoder=4, Heads=4
# Epoch [1/10] | Train Loss: 3.1617 | Val Loss: 2.6407 | Val Acc: 0.2236
# Epoch [2/10] | Train Loss: 2.4897 | Val Loss: 2.3238 | Val Acc: 0.2426
# Epoch [3/10] | Train Loss: 2.2474 | Val Loss: 2.1706 | Val Acc: 0.2513
# Epoch [4/10] | Train Loss: 2.1266 | Val Loss: 2.1151 | Val Acc: 0.2513
# Epoch [5/10] | Train Loss: 2.0567 | Val Loss: 2.0581 | Val Acc: 0.2470
# Epoch [6/10] | Train Loss: 1.9917 | Val Loss: 2.0388 | Val Acc: 0.2470
# Epoch [7/10] | Train Loss: 1.9428 | Val Loss: 2.0020 | Val Acc: 0.2530
# Epoch [8/10] | Train Loss: 1.9009 | Val Loss: 1.9864 | Val Acc: 0.2634
# Epoch [9/10] | Train Loss: 1.8645 | Val Loss: 1.9888 | Val Acc: 0.2513
# Epoch [10/10] | Train Loss: 1.8154 | Val Loss: 1.9674 | Val Acc: 0.2591
# ========================================== results ==========================================
# final training loss: 1.8154, final validation loss: 1.9674, final validation accuracy: 0.2591
# Average running time: 0.1785 seconds per epoch
# model complexity (number of parameters): 575735
# ============================================================================================
#
# ==========================================
# Running config: Encoder=4, Decoder=2, Heads=2
# Epoch [1/10] | Train Loss: 3.3495 | Val Loss: 2.8382 | Val Acc: 0.1802
# Epoch [2/10] | Train Loss: 2.5989 | Val Loss: 2.3926 | Val Acc: 0.2400
# Epoch [3/10] | Train Loss: 2.3303 | Val Loss: 2.2202 | Val Acc: 0.2435
# Epoch [4/10] | Train Loss: 2.1670 | Val Loss: 2.1394 | Val Acc: 0.2478
# Epoch [5/10] | Train Loss: 2.0992 | Val Loss: 2.1320 | Val Acc: 0.2444
# Epoch [6/10] | Train Loss: 2.0646 | Val Loss: 2.0689 | Val Acc: 0.2426
# Epoch [7/10] | Train Loss: 2.0104 | Val Loss: 2.0454 | Val Acc: 0.2513
# Epoch [8/10] | Train Loss: 1.9708 | Val Loss: 2.0327 | Val Acc: 0.2496
# Epoch [9/10] | Train Loss: 1.9695 | Val Loss: 2.0073 | Val Acc: 0.2600
# Epoch [10/10] | Train Loss: 1.9486 | Val Loss: 2.0074 | Val Acc: 0.2565
# ========================================== results ==========================================
# final training loss: 1.9486, final validation loss: 2.0074, final validation accuracy: 0.2565
# Average running time: 0.1456 seconds per epoch
# model complexity (number of parameters): 542199
# ============================================================================================
#
# ==========================================
# Running config: Encoder=4, Decoder=2, Heads=4
# Epoch [1/10] | Train Loss: 3.2298 | Val Loss: 2.7335 | Val Acc: 0.1924
# Epoch [2/10] | Train Loss: 2.5360 | Val Loss: 2.3488 | Val Acc: 0.2296
# Epoch [3/10] | Train Loss: 2.2850 | Val Loss: 2.1965 | Val Acc: 0.2374
# Epoch [4/10] | Train Loss: 2.1604 | Val Loss: 2.1130 | Val Acc: 0.2496
# Epoch [5/10] | Train Loss: 2.0877 | Val Loss: 2.0672 | Val Acc: 0.2513
# Epoch [6/10] | Train Loss: 2.0448 | Val Loss: 2.0391 | Val Acc: 0.2513
# Epoch [7/10] | Train Loss: 2.0198 | Val Loss: 2.0246 | Val Acc: 0.2556
# Epoch [8/10] | Train Loss: 1.9960 | Val Loss: 2.0113 | Val Acc: 0.2565
# Epoch [9/10] | Train Loss: 1.9451 | Val Loss: 1.9998 | Val Acc: 0.2539
# Epoch [10/10] | Train Loss: 1.9156 | Val Loss: 1.9857 | Val Acc: 0.2617
# ========================================== results ==========================================
# final training loss: 1.9156, final validation loss: 1.9857, final validation accuracy: 0.2617
# Average running time: 0.1458 seconds per epoch
# model complexity (number of parameters): 542199
# ============================================================================================
#
# ==========================================
# Running config: Encoder=4, Decoder=4, Heads=2
# Epoch [1/10] | Train Loss: 3.3677 | Val Loss: 2.8893 | Val Acc: 0.1698
# Epoch [2/10] | Train Loss: 2.6390 | Val Loss: 2.3958 | Val Acc: 0.2418
# Epoch [3/10] | Train Loss: 2.3065 | Val Loss: 2.2238 | Val Acc: 0.2426
# Epoch [4/10] | Train Loss: 2.1887 | Val Loss: 2.1374 | Val Acc: 0.2461
# Epoch [5/10] | Train Loss: 2.0878 | Val Loss: 2.0830 | Val Acc: 0.2487
# Epoch [6/10] | Train Loss: 2.0345 | Val Loss: 2.0460 | Val Acc: 0.2539
# Epoch [7/10] | Train Loss: 1.9897 | Val Loss: 2.0522 | Val Acc: 0.2548
# Epoch [8/10] | Train Loss: 1.9711 | Val Loss: 2.0082 | Val Acc: 0.2591
# Epoch [9/10] | Train Loss: 1.9252 | Val Loss: 1.9804 | Val Acc: 0.2591
# Epoch [10/10] | Train Loss: 1.9110 | Val Loss: 1.9667 | Val Acc: 0.2565
# ========================================== results ==========================================
# final training loss: 1.9110, final validation loss: 1.9667, final validation accuracy: 0.2565
# Average running time: 0.1994 seconds per epoch
# model complexity (number of parameters): 741751
# ============================================================================================
#
# ==========================================
# Running config: Encoder=4, Decoder=4, Heads=4
# Epoch [1/10] | Train Loss: 3.2403 | Val Loss: 2.7270 | Val Acc: 0.2062
# Epoch [2/10] | Train Loss: 2.5256 | Val Loss: 2.3773 | Val Acc: 0.2262
# Epoch [3/10] | Train Loss: 2.2677 | Val Loss: 2.1884 | Val Acc: 0.2470
# Epoch [4/10] | Train Loss: 2.1585 | Val Loss: 2.1326 | Val Acc: 0.2461
# Epoch [5/10] | Train Loss: 2.0948 | Val Loss: 2.0843 | Val Acc: 0.2487
# Epoch [6/10] | Train Loss: 2.0309 | Val Loss: 2.0485 | Val Acc: 0.2548
# Epoch [7/10] | Train Loss: 2.0006 | Val Loss: 2.0170 | Val Acc: 0.2652
# Epoch [8/10] | Train Loss: 1.9685 | Val Loss: 1.9997 | Val Acc: 0.2634
# Epoch [9/10] | Train Loss: 1.9119 | Val Loss: 1.9878 | Val Acc: 0.2426
# Epoch [10/10] | Train Loss: 1.9089 | Val Loss: 1.9913 | Val Acc: 0.2591
# ========================================== results ==========================================
# final training loss: 1.9089, final validation loss: 1.9913, final validation accuracy: 0.2591
# Average running time: 0.2000 seconds per epoch
# model complexity (number of parameters): 741751
# ============================================================================================
#
# Summary of all runs:
# Enc=1, Dec=1, Heads=2, final_train_loss=1.9204, final_val_loss=1.9808, final_val_acc=0.2522, time/epoch=0.0775s, params=193399
# Enc=1, Dec=1, Heads=4, final_train_loss=1.9173, final_val_loss=1.9964, final_val_acc=0.2600, time/epoch=0.0631s, params=193399
# Enc=1, Dec=2, Heads=2, final_train_loss=1.9144, final_val_loss=1.9870, final_val_acc=0.2496, time/epoch=0.1015s, params=293175
# Enc=1, Dec=2, Heads=4, final_train_loss=1.8741, final_val_loss=1.9652, final_val_acc=0.2600, time/epoch=0.0884s, params=293175
# Enc=2, Dec=2, Heads=2, final_train_loss=1.8791, final_val_loss=1.9627, final_val_acc=0.2548, time/epoch=0.1152s, params=376183
# Enc=2, Dec=2, Heads=4, final_train_loss=1.8428, final_val_loss=1.9685, final_val_acc=0.2600, time/epoch=0.1142s, params=376183
# Enc=2, Dec=4, Heads=2, final_train_loss=1.8673, final_val_loss=1.9597, final_val_acc=0.2600, time/epoch=0.1608s, params=575735
# Enc=2, Dec=4, Heads=4, final_train_loss=1.8154, final_val_loss=1.9674, final_val_acc=0.2591, time/epoch=0.1785s, params=575735
# Enc=4, Dec=2, Heads=2, final_train_loss=1.9486, final_val_loss=2.0074, final_val_acc=0.2565, time/epoch=0.1456s, params=542199
# Enc=4, Dec=2, Heads=4, final_train_loss=1.9156, final_val_loss=1.9857, final_val_acc=0.2617, time/epoch=0.1458s, params=542199
# Enc=4, Dec=4, Heads=2, final_train_loss=1.9110, final_val_loss=1.9667, final_val_acc=0.2565, time/epoch=0.1994s, params=741751
# Enc=4, Dec=4, Heads=4, final_train_loss=1.9089, final_val_loss=1.9913, final_val_acc=0.2591, time/epoch=0.2000s, params=741751
